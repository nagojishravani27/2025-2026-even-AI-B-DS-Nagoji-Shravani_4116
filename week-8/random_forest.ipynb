# %% [markdown]
# <a href="https://colab.research.google.com/github/nagojishravani27/2025-2026-even-AI-B-DS-Nagoji-Shravani_4116/blob/main/random_forest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### 31.Implement random forest for given dataset

# %%
from sklearn.ensemble import RandomForestClassifier
x=[[1,1],[1,0],[0,1],[0,0]]
y=[0,0,1,1]
model=RandomForestClassifier()
model.fit(x,y)
print(" Model prediction:",model.predict([[1,0]]))
# Out:
#  Model prediction: [0]
