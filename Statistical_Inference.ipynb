# %% [markdown]
# <a href="https://colab.research.google.com/github/nagojishravani27/2025-2026-even-AI-B-DS-Nagoji-Shravani_4116/blob/main/Statistical_Inference.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **WEEK_5: 10-03-26**

# %% [markdown]
# # 21.write the code to perform the following operations
# ##a.Z-score
# ##b.Statistical Inference
# ##c.Random variable model
# ##d.Central limit theorem
# ##e.Standardizations

# %%
#Z-score , Statistical inference, Random variable model, Central limit theorem, Standardizations
#Population Data
import numpy as np
import math
population=np.array([10,20,30,40,50,60,70])
N=len(population)
print("\nPopulation Size(N):",N)
mu=np.mean(population)
print("Population Mean(μ):",mu)
sigma2=np.var(population,ddof=0)
print("\nPopulation Variance(σ²):",sigma2)
sigma=np.sqrt(sigma2)
print("Population Standard Deviation(σ):",sigma)
#Sample data
sample=np.array([20,30,40,50])
n=len(sample)
print("\nSample Size(n):",n)
x_bar=np.mean(sample)
print("\nSample Mean(x̄):",x_bar)
s2=np.var(sample,ddof=1)
print("\nSample Variance(s2):",s2)
s=np.sqrt(s2)
print("\nSample Standard Deviation(s):",s)
#Central Limit Theorem
#Standard Error
SE=sigma/math.sqrt(n)
print("\nStandard Error(σ/√n):",SE)

#Z-transformation
z=(x_bar-mu)/SE
print("\nZ-score:",z)
# Out:
# Population Size(N): 7
# Population Mean(μ): 40.0
#
# Population Variance(σ²): 400.0
# Population Standard Deviation(σ): 20.0
#
# Sample Size(n): 4
#
# Sample Mean(x̄): 35.0
#
# Sample Variance(s2): 166.66666666666666
#
# Sample Standard Deviation(s): 12.909944487358056
#
# Standard Error(σ/√n): 10.0
#
# Z-score: -0.5
