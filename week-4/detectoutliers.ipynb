# %% [markdown]
# <a href="https://colab.research.google.com/github/nagojishravani27/2025-2026-even-AI-B-DS-Nagoji-Shravani_4116/blob/main/detectoutliers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 19.Write the python code to detect the outliers

# %%
import pandas as pd
data = {
    'name': ['A', 'B', 'C', 'D', 'E', 'F'],
    'Age': [13, 24, 25, 29, 120, 23]
     }
df = pd.DataFrame(data)
Q1 = df['Age'].quantile(0.25)
Q3 = df['Age'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
outliers = df[(df['Age'] < lower_bound) | (df['Age'] > upper_bound)]
print("Outliers:")
print(outliers)
# Out:
# Outliers:
#   name  Age
# 0    A   13
# 4    E  120
