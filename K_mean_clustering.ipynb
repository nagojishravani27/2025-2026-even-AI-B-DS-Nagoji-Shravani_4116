# %% [markdown]
# <a href="https://colab.research.google.com/github/nagojishravani27/2025-2026-even-AI-B-DS-Nagoji-Shravani_4116/blob/main/K_mean_clustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###34.Write a code to implement K-means clustering(unsupervised learning)algorithm

# %%
import numpy as np
A=np.array([[2,3],[3,4],[4,2]])
B=np.array([[8,7],[9,6],[10,8]])
P=np.array([5,5])
cA=A.mean(axis=0)
cB=B.mean(axis=0)
dA=np.linalg.norm(P-cA)
dB=np.linalg.norm(P-cB)
if dA<dB:
  print("Point belongs to cluster A")
else:
  print("Point belongs to cluster B")
# Out:
# Point belongs to cluster A
