# %% [markdown]
# <a href="https://colab.research.google.com/github/nagojishravani27/2025-2026-even-AI-B-DS-Nagoji-Shravani_4116/blob/main/Ego_Network.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###36.Write the code to implement the ego network or community networks

# %%
import networkx as nx
import matplotlib.pyplot as plt
G=nx.Graph()
G.add_edges_from([
  ('A','B'),
  ('A','C'),
  ('B','D'),
  ('C','D'),
  ('E','F'),
  ('E','G'),
  ('F','H'),
  ('G','H'),
  ('D','E')
])
from networkx.algorithms.community import greedy_modularity_communities
communities=greedy_modularity_communities(G)
for i,com in enumerate(communities):
  print(f"Community {i+1}:{list(com)}")
nx.draw(G,with_labels=True,node_size=3000)
plt.figure(figsize=(2,1))
plt.show()
# Out:
# Community 1:['D', 'B', 'A', 'C']
# Community 2:['E', 'F', 'G', 'H']
