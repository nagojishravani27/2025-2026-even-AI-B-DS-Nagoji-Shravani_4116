# %% [markdown]
# <a href="https://colab.research.google.com/github/nagojishravani27/2025-2026-even-AI-B-DS-Nagoji-Shravani_4116/blob/main/searching_%26sorting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **bubble sort,insertion sort ,linear search ,binary search**

# %%
# bubble sort
n = int(input("Enter number of elements: "))

arr = []

for i in range(n):
    arr.append(int(input(f"Enter element {i+1}: ")))

print("\nOriginal array:", arr)

# Bubble sort
for i in range(n-1):
    for j in range(n-1-i):
        if arr[j] > arr[j+1]:
            arr[j], arr[j+1] = arr[j+1], arr[j]

print("Sorted array:", arr)
# Out:
# Enter number of elements: 3
# Enter element 1: 1
# Enter element 2: 4
# Enter element 3: 6
#
# Original array: [1, 4, 6]
# Sorted array: [1, 4, 6]

# %%
# Sample data
arr = [64, 25, 12, 22, 11]

print("Original Array:", arr)
#Insertion Sort
def insertion_sort(lst):
    for i in range(1, len(lst)):
        key = lst[i]
        j = i - 1
        while j >= 0 and key < lst[j]:
            lst[j+1] = lst[j]
            j -= 1
        lst[j+1] = key
    return lst

insertion_sorted = insertion_sort(arr.copy())
print("Insertion Sorted Array:", insertion_sorted)
# Out:
# Original Array: [64, 25, 12, 22, 11]
# Insertion Sorted Array: [11, 12, 22, 25, 64]

# %%
#Linear search
n = int(input("enter no. of elements:"))
arr = []

for i in range(n):
    arr.append(int(input(f"enter element {i}:")))

key = int(input("enter element to search:"))

found = False

for i in range(n):
    if arr[i] == key:
        print(f"element {key} found at position {i+1}")
        found = True
        break

if not found:
    print("element not found")
# Out:
# enter no. of elements:4
# enter element 0:2
# enter element 1:13
# enter element 2:43
# enter element 3:55
# enter element to search:43
# element 43 found at position 3

# %%
# Binary Search
n = int(input("Enter number of elements: "))

arr = []

for i in range(n):
    arr.append(int(input(f"Enter element {i+1}: ")))

arr.sort()
print("\nSorted list:", arr)

key = int(input("Enter element to search: "))

low = 0
high = n - 1
found = False

while low <= high:
    mid = (low + high) // 2

    if arr[mid] == key:
        print(f"Element {key} found at position {mid+1}")
        found = True
        break
    elif key < arr[mid]:
        high = mid - 1
    else:
        low = mid + 1

if not found:
    print("Element not found")
# Out:
# Enter number of elements: 4
# Enter element 1: 12
# Enter element 2: 34
# Enter element 3: 15
# Enter element 4: 22
#
# Sorted list: [12, 15, 22, 34]
# Enter element to search: 22
# Element 22 found at position 3
