# %% [markdown]
# <a href="https://colab.research.google.com/github/nagojishravani27/2025-2026-even-AI-B-DS-Nagoji-Shravani_4116/blob/main/Lasso_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##32.Implement the lasso model

# %%
import numpy as np
from sklearn.linear_model import Lasso
X=np.array([[1,5,2],[2,6,4],[4,3,6],[7,6,2]])
Y=np.array([5,10,15,20])
model=Lasso(alpha=0.1)
model.fit(X,Y)
print("Coefficient:",model.coef_)
# Out:
# Coefficient: [2.38401043 0.37573922 0.8398587 ]
