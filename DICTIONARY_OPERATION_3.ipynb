# %% [markdown]
# <a href="https://colab.research.google.com/github/nagojishravani27/2025-2026-even-AI-B-DS-Nagoji-Shravani_4116/blob/main/DICTIONARY_OPERATION_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# DICTIONARY OPERATIONS

# Creating a dictionary
d = {
    "name": "Shravani",
    "age": 19,
    "course": "BTech"
}
print("Original dictionary:", d)

# Accessing values
print("Name:", d["name"])
print("Age:", d.get("age"))

# Adding a new key-value pair
d["college"] = "XYZ University"
print("After adding:", d)

# Updating value
d["age"] = 20
print("After updating:", d)

# Removing elements
d.pop("course")
print("After pop:", d)

removed_item = d.popitem()
print("After popitem:", d)
print("Removed item:", removed_item)

# Keys, values, items
print("Keys:", d.keys())
print("Values:", d.values())
print("Items:", d.items())

# Membership
print("Is 'name' a key?", "name" in d)

# Length
print("Length of dictionary:", len(d))

# Looping through dictionary
print("Looping through keys:")
for key in d:
    print(key, ":", d[key])

print("Looping through key-value pairs:")
for k, v in d.items():
    print(k, "->", v)

# Copying dictionary
d_copy = d.copy()
print("Copied dictionary:", d_copy)

# Updating using update()
d.update({"city": "Hyderabad", "age": 21})
print("After update():", d)

# Nested dictionary
student = {
    "id": 1,
    "info": {
        "name": "Amit",
        "marks": 90
    }
}
print("Nested dictionary value:", student["info"]["marks"])

# Clearing dictionary
d.clear()
print("After clear:", d)
# Out:
# Original dictionary: {'name': 'Shravani', 'age': 19, 'course': 'BTech'}
# Name: Shravani
# Age: 19
# After adding: {'name': 'Shravani', 'age': 19, 'course': 'BTech', 'college': 'XYZ University'}
# After updating: {'name': 'Shravani', 'age': 20, 'course': 'BTech', 'college': 'XYZ University'}
# After pop: {'name': 'Shravani', 'age': 20, 'college': 'XYZ University'}
# After popitem: {'name': 'Shravani', 'age': 20}
# Removed item: ('college', 'XYZ University')
# Keys: dict_keys(['name', 'age'])
# Values: dict_values(['Shravani', 20])
# Items: dict_items([('name', 'Shravani'), ('age', 20)])
# Is 'name' a key? True
# Length of dictionary: 2
# Looping through keys:
# name : Shravani
# age : 20
# Looping through key-value pairs:
# name -> Shravani
# age -> 20
# Copied dictionary: {'name': 'Shravani', 'age': 20}
# After update(): {'name': 'Shravani', 'age': 21, 'city': 'Hyderabad'}
# Nested dictionary value: 90
# After clear: {}
