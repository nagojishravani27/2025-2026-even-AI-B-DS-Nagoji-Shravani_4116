# %% [markdown]
# <a href="https://colab.research.google.com/github/nagojishravani27/2025-2026-even-AI-B-DS-Nagoji-Shravani_4116/blob/main/list_oeration_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# LIST OPERATIONS

# Creating a list
lst = [10, 20, 30, 40]
print("Initial list:", lst)

# Accessing elements
print("First element:", lst[0])
print("Last element:", lst[-1])

# Adding elements
lst.append(50)
print("After append:", lst)

lst.insert(2, 25)
print("After insert:", lst)

lst.extend([60, 70])
print("After extend:", lst)

# Removing elements
lst.remove(25)
print("After remove:", lst)

lst.pop()
print("After pop:", lst)

lst.pop(1)
print("After pop at index 1:", lst)

# Updating element
lst[0] = 100
print("After updating:", lst)

# Searching
print("Index of 30:", lst.index(30))
print("Count of 20:", lst.count(20))

# Sorting
lst.sort()
print("After sort:", lst)

lst.sort(reverse=True)
print("After reverse sort:", lst)

# Reversing
lst.reverse()
print("After reverse:", lst)

# Copying
new_lst = lst.copy()
print("Copied list:", new_lst)

# Length
print("Length of list:", len(lst))

# Membership
print("Is 40 in list?", 40 in lst)

# Looping
print("Elements in list:")
for item in lst:
    print(item)

# List comprehension
squares = [x*x for x in lst]
print("Squares of elements:", squares)

# Clearing list
lst.clear()
print("After clear:", lst)
