# %% [markdown]
# <a href="https://colab.research.google.com/github/nagojishravani27/2025-2026-even-AI-B-DS-Nagoji-Shravani_4116/blob/main/SELECTIONSORT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Selection data

import pandas as pd

data = {
    "ID": [101, 102, 103, 104, 105],
    "Name": ["sravani", "ammulya", "yashu", "David", "charan"],
    "Age": [22, 25, 23, 24, 26],
    "Marks": [85, 78, 92, 88, 90]
}

df = pd.DataFrame(data)

print(df)
print(df["Name"])
print(df["Marks"])

df[["Name", "Marks"]]

print("location 0", df.iloc[0])
print("location 1 to 4", df.iloc[1:4])
print("location 1 to 3", df.iloc[0:3, 1:3])
